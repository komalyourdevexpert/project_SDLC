# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import sklearn as sk
import pandas as pd
from sklearn.linear_model import LinearRegression

fname = r'C:\Users\komal\OneDrive\Desktop\BA\orders.xlsx'

print(fname)

mydata = pd.read_excel(fname,'Orders')

mydata.head()

mydata.describe()
var_names = list(mydata)
x = mydata['Sales'].values
y = mydata['Profit'].values

plt.scatter(x,y)

reg = LinearRegression()
x = x.reshape(-1,1)
y = y.reshape(-1,1)
reg.fit(x,y)
reg.intercept_
reg.coef_
reg.score(x,y)


var_names = list(mydata)

x = mydata['Sales'].values
y = mydata['Profit'].values
           
plt.scatter(x,y)
 
reg = LinearRegression()
x = x.reshape(-1,1)
y = y.reshape(-1,1)

reg.fit(x,y)

reg.intercept_

reg.coef_

reg.score(x,y)
# Out:
# C:\Users\komal\OneDrive\Desktop\BA\orders.xlsx
# 0.2351455759464044
